# %%
# Task 2 Logic
first_letter = "B"
ascii_val = ord(first_letter) # This gets 66
loops = 6
seed_num = 1

# Calculate the forensic signature
verification_hash = (ascii_val * seed_num) - loops

print(f"Forensic Signature: {verification_hash}")
# Out:
# Forensic Signature: 60
